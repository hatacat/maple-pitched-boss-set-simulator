# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from core import *
from simulate import *

# %%
# init value
p=0.02 # 칠흑 드랍율
n=5000000 # 시뮬레이션 횟수 (1백만)
week=104 # 104 주 (2년)
target = 22 # 칠흑 완성 목표
star=[22,22,22,22,22,22,0] # [루컨,마깃,몽벨,거공,커포,고근,마도서]
star_next=[22,22,22,22,22,22,0] # [루컨,마깃,몽벨,거공,커포,고근,마도서]

exchange_rate_dict = {'all_state': 1.1 , 'boss_damage': 11.74 , 'attack': 3.39, 'ignore_defense': 7.88, 'critical_damage': 32.63}
state_to_final=0.01035

# additional_option list
additional_option_100={140:121, 145:121, 150:121 ,160:132 ,200:149}
additional_option_300={140:129, 145:129, 150:129 ,160:141 ,200:159}

# cashing
cashed_data=cashing_final_damage_spare(star,star_next,additional_option_100,exchange_rate_dict,state_to_final)

simulation=Simulate_spare(p,n,week,target,star,star_next,exchange_rate_dict,state_to_final,cashed_data)
simulation.simulating()
simulation.plot()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:42<00:00, 23.35it/s]
# 104주 동안 22성 칠흑셋 완성 확률
# 7 개 확률 :  0.80 %
# 6 개 확률 :  5.77 %
# 5 개 확률 : 17.63 %
# 4 개 확률 : 29.15 %
# 3 개 확률 : 27.69 %
# 2 개 확률 : 14.78 %
# 1 개 확률 :  3.86 %
# 0 개 확률 :  0.32 %
#
# 104주 동안 22성 칠흑 완성 확률(스페어 강화)
# 7 개 확률 :  0.00 %
# 6 개 확률 :  0.01 %
# 5 개 확률 :  0.18 %
# 4 개 확률 :  1.68 %
# 3 개 확률 :  9.36 %
# 2 개 확률 : 28.89 %
# 1 개 확률 : 42.64 %
# 0 개 확률 : 17.25 %
#
# 104주 동안 22성 칠흑셋 최종뎀 증가량
# 평균 :  8.88 %
# 표준편차 :  4.70 %
#
# 상위 1% : 18.24 %
# 상위 10% : 15.33 %
# 상위 25% : 12.09 %
# 중간값 :  8.70 %
# 하위 25% :  5.10 %
# 하위 10% :  3.00 %
# 하위 1% :  0.47 %

# %%
# init value
target = 21 # 칠흑 완성 목표
star=[21,21,21,21,21,21,0] # [루컨,마깃,몽벨,거공,커포,고근,마도서]
star_next=[22,22,22,22,22,22,0] # [루컨,마깃,몽벨,거공,커포,고근,마도서]

# cashing
cashed_data=cashing_final_damage_spare(star,star_next,additional_option_100,exchange_rate_dict,state_to_final)

simulation=Simulate_spare(p,n,week,target,star,star_next,exchange_rate_dict,state_to_final,cashed_data)
simulation.simulating()
simulation.plot()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:41<00:00, 23.93it/s]
# 104주 동안 21성 칠흑셋 완성 확률
# 7 개 확률 :  4.77 %
# 6 개 확률 : 18.58 %
# 5 개 확률 : 30.42 %
# 4 개 확률 : 27.13 %
# 3 개 확률 : 14.16 %
# 2 개 확률 :  4.24 %
# 1 개 확률 :  0.66 %
# 0 개 확률 :  0.04 %
#
# 104주 동안 22성 칠흑 완성 확률(스페어 강화)
# 7 개 확률 :  0.00 %
# 6 개 확률 :  0.05 %
# 5 개 확률 :  0.62 %
# 4 개 확률 :  4.09 %
# 3 개 확률 : 15.45 %
# 2 개 확률 : 32.92 %
# 1 개 확률 : 34.84 %
# 0 개 확률 : 12.02 %
#
# 104주 동안 21성 칠흑셋 최종뎀 증가량
# 평균 : 10.03 %
# 표준편차 :  4.09 %
#
# 상위 1% : 18.82 %
# 상위 10% : 15.02 %
# 상위 25% : 13.19 %
# 중간값 : 10.31 %
# 하위 25% :  7.04 %
# 하위 10% :  4.24 %
# 하위 1% :  0.88 %

# %%
# init value
target = 20 # 칠흑 완성 목표
star=[20,20,20,20,20,20,0] # [루컨,마깃,몽벨,거공,커포,고근,마도서]
star_next=[22,22,22,22,22,22,0] # [루컨,마깃,몽벨,거공,커포,고근,마도서]

# cashing
cashed_data=cashing_final_damage_spare(star,star_next,additional_option_100,exchange_rate_dict,state_to_final)

simulation=Simulate_spare(p,n,week,target,star,star_next,exchange_rate_dict,state_to_final,cashed_data)
simulation.simulating()
simulation.plot()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:41<00:00, 23.97it/s]
# 104주 동안 20성 칠흑셋 완성 확률
# 7 개 확률 :  9.41 %
# 6 개 확률 : 26.74 %
# 5 개 확률 : 32.24 %
# 4 개 확률 : 21.25 %
# 3 개 확률 :  8.26 %
# 2 개 확률 :  1.86 %
# 1 개 확률 :  0.22 %
# 0 개 확률 :  0.01 %
#
# 104주 동안 22성 칠흑 완성 확률(스페어 강화)
# 7 개 확률 :  0.00 %
# 6 개 확률 :  0.10 %
# 5 개 확률 :  1.02 %
# 4 개 확률 :  5.72 %
# 3 개 확률 : 18.43 %
# 2 개 확률 : 33.70 %
# 1 개 확률 : 31.08 %
# 0 개 확률 :  9.94 %
#
# 104주 동안 20성 칠흑셋 최종뎀 증가량
# 평균 :  9.10 %
# 표준편차 :  3.62 %
#
# 상위 1% : 16.56 %
# 상위 10% : 13.37 %
# 상위 25% : 11.62 %
# 중간값 :  9.28 %
# 하위 25% :  6.62 %
# 하위 10% :  4.18 %
# 하위 1% :  0.77 %

# %%
# init value
target = 19 # 칠흑 완성 목표
star=[19,19,19,19,19,19,0] # [루컨,마깃,몽벨,거공,커포,고근,마도서]
star_next=[22,22,22,22,22,22,0] # [루컨,마깃,몽벨,거공,커포,고근,마도서]

# cashing
cashed_data=cashing_final_damage_spare(star,star_next,additional_option_100,exchange_rate_dict,state_to_final)

simulation=Simulate_spare(p,n,week,target,star,star_next,exchange_rate_dict,state_to_final,cashed_data)
simulation.simulating()
simulation.plot()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:43<00:00, 22.91it/s]
# 104주 동안 19성 칠흑셋 완성 확률
# 7 개 확률 : 23.37 %
# 6 개 확률 : 37.89 %
# 5 개 확률 : 26.13 %
# 4 개 확률 : 10.00 %
# 3 개 확률 :  2.28 %
# 2 개 확률 :  0.31 %
# 1 개 확률 :  0.02 %
# 0 개 확률 :  0.00 %
#
# 104주 동안 22성 칠흑 완성 확률(스페어 강화)
# 7 개 확률 :  0.01 %
# 6 개 확률 :  0.26 %
# 5 개 확률 :  2.09 %
# 4 개 확률 :  9.09 %
# 3 개 확률 : 22.98 %
# 2 개 확률 : 33.47 %
# 1 개 확률 : 25.08 %
# 0 개 확률 :  7.01 %
#
# 104주 동안 19성 칠흑셋 최종뎀 증가량
# 평균 :  8.43 %
# 표준편차 :  3.46 %
#
# 상위 1% : 16.62 %
# 상위 10% : 13.05 %
# 상위 25% : 10.82 %
# 중간값 :  8.38 %
# 하위 25% :  6.01 %
# 하위 10% :  4.13 %
# 하위 1% :  0.50 %

# %%
# init value
target = 18 # 칠흑 완성 목표
star=[18,18,18,18,18,18,0] # [루컨,마깃,몽벨,거공,커포,고근,마도서]
star_next=[22,22,22,22,22,22,0] # [루컨,마깃,몽벨,거공,커포,고근,마도서]

# cashing
cashed_data=cashing_final_damage_spare(star,star_next,additional_option_100,exchange_rate_dict,state_to_final)

simulation=Simulate_spare(p,n,week,target,star,star_next,exchange_rate_dict,state_to_final,cashed_data)
simulation.simulating()
simulation.plot()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:43<00:00, 22.82it/s]
# 104주 동안 18성 칠흑셋 완성 확률
# 7 개 확률 : 35.66 %
# 6 개 확률 : 39.65 %
# 5 개 확률 : 18.86 %
# 4 개 확률 :  4.97 %
# 3 개 확률 :  0.78 %
# 2 개 확률 :  0.07 %
# 1 개 확률 :  0.00 %
# 0 개 확률 :  0.00 %
#
# 104주 동안 22성 칠흑 완성 확률(스페어 강화)
# 7 개 확률 :  0.03 %
# 6 개 확률 :  0.43 %
# 5 개 확률 :  2.99 %
# 4 개 확률 : 11.38 %
# 3 개 확률 : 25.31 %
# 2 개 확률 : 32.47 %
# 1 개 확률 : 21.77 %
# 0 개 확률 :  5.63 %
#
# 104주 동안 18성 칠흑셋 최종뎀 증가량
# 평균 :  6.85 %
# 표준편차 :  3.73 %
#
# 상위 1% : 15.58 %
# 상위 10% : 11.83 %
# 상위 25% :  8.92 %
# 중간값 :  6.04 %
# 하위 25% :  4.39 %
# 하위 10% :  2.32 %
# 하위 1% :  0.00 %

# %%
# init value
target = 17 # 칠흑 완성 목표
star=[17,17,17,17,17,17,0] # [루컨,마깃,몽벨,거공,커포,고근,마도서]
star_next=[22,22,22,22,22,22,0] # [루컨,마깃,몽벨,거공,커포,고근,마도서]

# cashing
cashed_data=cashing_final_damage_spare(star,star_next,additional_option_100,exchange_rate_dict,state_to_final)

simulation=Simulate_spare(p,n,week,target,star,star_next,exchange_rate_dict,state_to_final,cashed_data)
simulation.simulating()
simulation.plot()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:44<00:00, 22.41it/s]
# 104주 동안 17성 칠흑셋 완성 확률
# 7 개 확률 : 40.10 %
# 6 개 확률 : 39.15 %
# 5 개 확률 : 16.37 %
# 4 개 확률 :  3.79 %
# 3 개 확률 :  0.53 %
# 2 개 확률 :  0.04 %
# 1 개 확률 :  0.00 %
# 0 개 확률 :  0.00 %
#
# 104주 동안 22성 칠흑 완성 확률(스페어 강화)
# 7 개 확률 :  0.03 %
# 6 개 확률 :  0.50 %
# 5 개 확률 :  3.33 %
# 4 개 확률 : 12.15 %
# 3 개 확률 : 25.97 %
# 2 개 확률 : 32.02 %
# 1 개 확률 : 20.80 %
# 0 개 확률 :  5.21 %
#
# 104주 동안 17성 칠흑셋 최종뎀 증가량
# 평균 :  4.94 %
# 표준편차 :  3.95 %
#
# 상위 1% : 14.45 %
# 상위 10% : 10.27 %
# 상위 25% :  6.84 %
# 중간값 :  4.17 %
# 하위 25% :  2.31 %
# 하위 10% :  0.00 %
# 하위 1% :  0.00 %

# %%
# init value
target = 21 # 칠흑 완성 목표
star=[21,21,21,18,21,21,0] # [루컨,마깃,몽벨,거공,커포,고근,마도서]
star_next=[22,22,22,22,22,22,0] # [루컨,마깃,몽벨,거공,커포,고근,마도서]

# cashing
cashed_data=cashing_final_damage_spare(star,star_next,additional_option_100,exchange_rate_dict,state_to_final)

simulation=Simulate_spare(p,n,week,target,star,star_next,exchange_rate_dict,state_to_final,cashed_data)
simulation.simulating()
simulation.plot()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:44<00:00, 22.71it/s]
# 104주 동안 21성 칠흑셋 완성 확률
# 7 개 확률 :  6.68 %
# 6 개 확률 : 22.87 %
# 5 개 확률 : 32.47 %
# 4 개 확률 : 24.57 %
# 3 개 확률 : 10.56 %
# 2 개 확률 :  2.54 %
# 1 개 확률 :  0.31 %
# 0 개 확률 :  0.01 %
#
# 104주 동안 22성 칠흑 완성 확률(스페어 강화)
# 7 개 확률 :  0.00 %
# 6 개 확률 :  0.08 %
# 5 개 확률 :  0.83 %
# 4 개 확률 :  5.03 %
# 3 개 확률 : 17.36 %
# 2 개 확률 : 33.66 %
# 1 개 확률 : 32.42 %
# 0 개 확률 : 10.61 %
#
# 104주 동안 21성 칠흑셋 최종뎀 증가량
# 평균 : 10.11 %
# 표준편차 :  3.56 %
#
# 상위 1% : 18.09 %
# 상위 10% : 14.72 %
# 상위 25% : 12.47 %
# 중간값 : 10.11 %
# 하위 25% :  7.75 %
# 하위 10% :  5.53 %
# 하위 1% :  2.10 %

# %%
# init value
target = 21 # 칠흑 완성 목표
star=[21,21,21,19,21,21,0] # [루컨,마깃,몽벨,거공,커포,고근,마도서]
star_next=[22,22,22,22,22,22,0] # [루컨,마깃,몽벨,거공,커포,고근,마도서]

# cashing
cashed_data=cashing_final_damage_spare(star,star_next,additional_option_100,exchange_rate_dict,state_to_final)

simulation=Simulate_spare(p,n,week,target,star,star_next,exchange_rate_dict,state_to_final,cashed_data)
simulation.simulating()
simulation.plot()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:43<00:00, 22.76it/s]
# 104주 동안 21성 칠흑셋 완성 확률
# 7 개 확률 :  6.21 %
# 6 개 확률 : 21.84 %
# 5 개 확률 : 31.97 %
# 4 개 확률 : 25.20 %
# 3 개 확률 : 11.43 %
# 2 개 확률 :  2.95 %
# 1 개 확률 :  0.39 %
# 0 개 확률 :  0.02 %
#
# 104주 동안 22성 칠흑 완성 확률(스페어 강화)
# 7 개 확률 :  0.00 %
# 6 개 확률 :  0.07 %
# 5 개 확률 :  0.78 %
# 4 개 확률 :  4.78 %
# 3 개 확률 : 16.83 %
# 2 개 확률 : 33.44 %
# 1 개 확률 : 33.08 %
# 0 개 확률 : 11.01 %
#
# 104주 동안 21성 칠흑셋 최종뎀 증가량
# 평균 : 10.25 %
# 표준편차 :  3.63 %
#
# 상위 1% : 18.09 %
# 상위 10% : 14.92 %
# 상위 25% : 12.76 %
# 중간값 : 10.32 %
# 하위 25% :  7.84 %
# 하위 10% :  5.32 %
# 하위 1% :  1.82 %

# %%
# init value
target = 21 # 칠흑 완성 목표
star=[21,21,21,17,21,21,0] # [루컨,마깃,몽벨,거공,커포,고근,마도서]
star_next=[22,22,22,22,22,22,0] # [루컨,마깃,몽벨,거공,커포,고근,마도서]

# cashing
cashed_data=cashing_final_damage_spare(star,star_next,additional_option_100,exchange_rate_dict,state_to_final)

simulation=Simulate_spare(p,n,week,target,star,star_next,exchange_rate_dict,state_to_final,cashed_data)
simulation.simulating()
simulation.plot()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:48<00:00, 20.46it/s]
# 104주 동안 21성 칠흑셋 완성 확률
# 7 개 확률 :  6.84 %
# 6 개 확률 : 23.17 %
# 5 개 확률 : 32.59 %
# 4 개 확률 : 24.39 %
# 3 개 확률 : 10.31 %
# 2 개 확률 :  2.40 %
# 1 개 확률 :  0.28 %
# 0 개 확률 :  0.01 %
#
# 104주 동안 22성 칠흑 완성 확률(스페어 강화)
# 7 개 확률 :  0.00 %
# 6 개 확률 :  0.08 %
# 5 개 확률 :  0.86 %
# 4 개 확률 :  5.14 %
# 3 개 확률 : 17.56 %
# 2 개 확률 : 33.71 %
# 1 개 확률 : 32.17 %
# 0 개 확률 : 10.48 %
#
# 104주 동안 21성 칠흑셋 최종뎀 증가량
# 평균 :  9.78 %
# 표준편차 :  3.60 %
#
# 상위 1% : 18.09 %
# 상위 10% : 14.71 %
# 상위 25% : 12.16 %
# 중간값 :  9.69 %
# 하위 25% :  7.32 %
# 하위 10% :  5.15 %
# 하위 1% :  2.22 %

# %%
# init value
target = 19 # 칠흑 완성 목표
star=[19,19,19,17,19,19,0] # [루컨,마깃,몽벨,거공,커포,고근,마도서]
star_next=[22,22,22,22,22,22,0] # [루컨,마깃,몽벨,거공,커포,고근,마도서]

# cashing
cashed_data=cashing_final_damage_spare(star,star_next,additional_option_100,exchange_rate_dict,state_to_final)

simulation=Simulate_spare(p,n,week,target,star,star_next,exchange_rate_dict,state_to_final,cashed_data)
simulation.simulating()
simulation.plot()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:48<00:00, 20.66it/s]
# 104주 동안 19성 칠흑셋 완성 확률
# 7 개 확률 : 25.55 %
# 6 개 확률 : 38.68 %
# 5 개 확률 : 24.88 %
# 4 개 확률 :  8.80 %
# 3 개 확률 :  1.85 %
# 2 개 확률 :  0.23 %
# 1 개 확률 :  0.02 %
# 0 개 확률 :  0.00 %
#
# 104주 동안 22성 칠흑 완성 확률(스페어 강화)
# 7 개 확률 :  0.02 %
# 6 개 확률 :  0.29 %
# 5 개 확률 :  2.27 %
# 4 개 확률 :  9.58 %
# 3 개 확률 : 23.55 %
# 2 개 확률 : 33.29 %
# 1 개 확률 : 24.34 %
# 0 개 확률 :  6.66 %
#
# 104주 동안 19성 칠흑셋 최종뎀 증가량
# 평균 :  7.96 %
# 표준편차 :  3.44 %
#
# 상위 1% : 16.62 %
# 상위 10% : 12.53 %
# 상위 25% : 10.28 %
# 중간값 :  7.73 %
# 하위 25% :  5.51 %
# 하위 10% :  3.63 %
# 하위 1% :  0.84 %
